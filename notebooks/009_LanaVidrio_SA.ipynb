# %% [markdown]
# # Cocinas_Lana de vidrio_ Sin Agua

# %%
import pandas as pd

# %% [markdown]
# ## cocina 1

# %%
# Importar dato faltante
# El data frame faltante se asigna con la variable "df1_0"

# %%
df1_0 = pd.read_csv('../data/001_raw/Cocina_1__1_LITROS_LANA__DE_VIDRIO_01_02_24.csv', index_col=0, parse_dates=True)


df1_0 = df1_0.rename_axis(index='Fecha')

df1_0 = df1_0.rename({'Tipo K, °C (SEN S/N: 21654196, LBL: T 1p)':'T_p1',
                'Tipo T, °C (SEN S/N: 21654196, LBL: T 1a)':'T_m1',
                'Tipo K, °C (SEN S/N: 21654196, LBL: T 1 iv)':'T_vi1',
                'Tipo K, °C (SEN S/N: 21654196, LBL: T  1 ev)':'T_ve1'
                  }, axis = 1)
# Out:
# C:\Users\USER.V\AppData\Local\Temp\ipykernel_16764\3197079014.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df1_0 = pd.read_csv('../data/001_raw/Cocina_1__1_LITROS_LANA__DE_VIDRIO_01_02_24.csv', index_col=0, parse_dates=True)

# %%
df1_0
# Out:
#                       T_p1   T_m1  T_vi1  T_ve1
# Fecha
# 2024-01-29 08:10:00  31.90  26.64  32.48  28.75
# 2024-01-29 08:11:00  32.02  26.72  32.68  28.98
# 2024-01-29 08:12:00  32.23  26.83  32.84  29.02
# 2024-01-29 08:13:00  32.44  26.96  32.94  29.12
# 2024-01-29 08:14:00  32.59  27.01  33.00  29.11
# ...                    ...    ...    ...    ...
# 2024-02-01 08:03:00  27.85  27.04  25.79  23.31
# 2024-02-01 08:04:00  27.84  27.10  25.69  23.30
# 2024-02-01 08:05:00  27.86  27.06  25.59  23.25
# 2024-02-01 08:06:00  27.73  27.09  25.51  23.22
# 2024-02-01 08:07:00  27.56  27.04  25.69  23.58
#
# [4318 rows x 4 columns]

# %%
f = '../data/001_raw/Cocina_1__SIN_AGUA_LANA__DE_VIDRIO_05_02_24.csv'

df1_1 = pd.read_csv(f, index_col = 0, parse_dates = True)
# renombrar el index
df1_1 = df1_1.rename_axis(index='Fecha')

df1_1 = df1_1.rename({'Tipo K, °C (SEN S/N: 21654196, LBL: T 1p)':'T_p1',
                'Tipo T, °C (SEN S/N: 21654196, LBL: T 1C)':'T_m1',
                'Tipo K, °C (SEN S/N: 21654196, LBL: T 1 iv)':'T_vi1',
                'Tipo K, °C (SEN S/N: 21654196, LBL: T  1 ev)':'T_ve1'
                  }, axis = 1)
# Out:
# C:\Users\USER.V\AppData\Local\Temp\ipykernel_16764\2146523565.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df1_1 = pd.read_csv(f, index_col = 0, parse_dates = True)

# %%
df1_1
# Out:
#                        T_p1    T_m1  T_vi1  T_ve1
# Fecha
# 2024-02-01 08:15:00   27.93   27.41  25.37  22.95
# 2024-02-01 08:16:00   27.91   27.41  25.36  22.98
# 2024-02-01 08:17:00   27.95   22.81  25.18  23.00
# 2024-02-01 08:18:00   28.03  213.10  25.02  23.16
# 2024-02-01 08:19:00   28.06   21.76  24.87  23.00
# ...                     ...     ...    ...    ...
# 2024-02-05 09:58:00  102.15   85.36  79.07  59.51
# 2024-02-05 09:59:00  102.70   75.93  79.53  60.10
# 2024-02-05 10:00:00  103.35   83.82  80.21  60.64
# 2024-02-05 10:01:00  104.01  135.67  80.75  61.39
# 2024-02-05 10:02:00  104.45  278.74  81.35  61.34
#
# [5868 rows x 4 columns]

# %%
# df1_1.plot(subplots = True)

# %% [markdown]
# <!-- ### Concatenar cocinas 1 -->

# %%
df1 = pd.concat([df1_0, df1_1], axis = 0)
df1
# Out:
#                        T_p1    T_m1  T_vi1  T_ve1
# Fecha
# 2024-01-29 08:10:00   31.90   26.64  32.48  28.75
# 2024-01-29 08:11:00   32.02   26.72  32.68  28.98
# 2024-01-29 08:12:00   32.23   26.83  32.84  29.02
# 2024-01-29 08:13:00   32.44   26.96  32.94  29.12
# 2024-01-29 08:14:00   32.59   27.01  33.00  29.11
# ...                     ...     ...    ...    ...
# 2024-02-05 09:58:00  102.15   85.36  79.07  59.51
# 2024-02-05 09:59:00  102.70   75.93  79.53  60.10
# 2024-02-05 10:00:00  103.35   83.82  80.21  60.64
# 2024-02-05 10:01:00  104.01  135.67  80.75  61.39
# 2024-02-05 10:02:00  104.45  278.74  81.35  61.34
#
# [10186 rows x 4 columns]

# %% [markdown]
# ## cocina 2

# %%
# Importar dato faltante
# El data frame faltante se asigna con la variable "df2_0"

# %%
df2_0 = pd.read_csv('../data/001_raw/Cocina_2___1_LITRO__LANA_DE_VIDRIO_01_02_24..csv', index_col=0, parse_dates=True)


df2_0 = df2_0.rename_axis(index='Fecha')

df2_0 = df2_0.rename({'Tipo K, °C (SEN S/N: 20939342, LBL: T 2p)':'T_p2',
                'Tipo T, °C (SEN S/N: 20939342, LBL: T 2A)':'T_m2',
                'Tipo K, °C (SEN S/N: 20939342, LBL: T 2iv)':'T_vi2',
                'Tipo K, °C (SEN S/N: 20939342, LBL: T 2ev)':'T_ve2'
                  }, axis = 1)
# Out:
# C:\Users\USER.V\AppData\Local\Temp\ipykernel_16764\1313813427.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df2_0 = pd.read_csv('../data/001_raw/Cocina_2___1_LITRO__LANA_DE_VIDRIO_01_02_24..csv', index_col=0, parse_dates=True)

# %%
df2_0
# Out:
#                       T_p2   T_m2  T_vi2  T_ve2
# Fecha
# 2024-01-29 08:10:00  31.42  26.55  33.92  29.61
# 2024-01-29 08:11:00  31.53  26.72  34.00  29.74
# 2024-01-29 08:12:00  31.63  26.81  34.23  29.63
# 2024-01-29 08:13:00  31.81  26.91  34.39  29.63
# 2024-01-29 08:14:00  31.90  27.05  34.47  29.70
# ...                    ...    ...    ...    ...
# 2024-02-01 08:05:00  28.70  26.20  25.84  23.90
# 2024-02-01 08:06:00  28.71  26.22  25.78  23.92
# 2024-02-01 08:07:00  28.71  26.26  25.75  23.96
# 2024-02-01 08:08:00  28.72  26.29  25.76  23.95
# 2024-02-01 08:09:00  28.69  26.32  25.66  23.90
#
# [4320 rows x 4 columns]

# %%
g = '../data/001_raw/Cocina_2___SIN_AGUA__LANA_DE_VIDRIO_05_02_24..csv'

df2_1 = pd.read_csv(g, index_col = 0, parse_dates = True)
# renombrar el index
df2_1 = df2_1.rename_axis(index='Fecha')

df2_1 = df2_1.rename({'Tipo K, °C (SEN S/N: 20939342, LBL: T 2p)':'T_p2',
                'Tipo T, °C (SEN S/N: 20939342, LBL: T 2C)':'T_m2',
                'Tipo K, °C (SEN S/N: 20939342, LBL: T 2iv)':'T_vi2',
                'Tipo K, °C (SEN S/N: 20939342, LBL: T 2ev)':'T_ve2'
                  }, axis = 1)
# Out:
# C:\Users\USER.V\AppData\Local\Temp\ipykernel_16764\1971873636.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df2_1 = pd.read_csv(g, index_col = 0, parse_dates = True)

# %%
df2_1
# Out:
#                        T_p2   T_m2  T_vi2   T_ve2
# Fecha
# 2024-02-01 08:15:00   28.75  26.51  25.61   23.73
# 2024-02-01 08:16:00   28.77  26.58  25.57   23.77
# 2024-02-01 08:17:00   28.85  26.57  25.61   23.77
# 2024-02-01 08:18:00   28.82  26.62  25.59   23.80
# 2024-02-01 08:19:00   28.82  26.65  25.63   23.77
# ...                     ...    ...    ...     ...
# 2024-02-05 10:00:00  103.79  86.30  83.46   64.97
# 2024-02-05 10:01:00  104.21  86.48  83.93   65.65
# 2024-02-05 10:02:00  104.74  85.97  84.32   66.14
# 2024-02-05 10:03:00  105.41  86.23  84.66   65.46
# 2024-02-05 10:04:00  105.67  88.18  85.11  157.64
#
# [5870 rows x 4 columns]

# %% [markdown]
# <!-- ### Concatenar cocinas 2 -->

# %%
df2 = pd.concat([df2_0, df2_1], axis = 0)
df2
# Out:
#                        T_p2   T_m2  T_vi2   T_ve2
# Fecha
# 2024-01-29 08:10:00   31.42  26.55  33.92   29.61
# 2024-01-29 08:11:00   31.53  26.72  34.00   29.74
# 2024-01-29 08:12:00   31.63  26.81  34.23   29.63
# 2024-01-29 08:13:00   31.81  26.91  34.39   29.63
# 2024-01-29 08:14:00   31.90  27.05  34.47   29.70
# ...                     ...    ...    ...     ...
# 2024-02-05 10:00:00  103.79  86.30  83.46   64.97
# 2024-02-05 10:01:00  104.21  86.48  83.93   65.65
# 2024-02-05 10:02:00  104.74  85.97  84.32   66.14
# 2024-02-05 10:03:00  105.41  86.23  84.66   65.46
# 2024-02-05 10:04:00  105.67  88.18  85.11  157.64
#
# [10190 rows x 4 columns]

# %% [markdown]
# ## cocina 3

# %%
# Importar dato faltante
# El data frame faltante se asigna con la variable "df3_0"

# %%
df3_0 = pd.read_csv('../data/001_raw/Cocina_3__1_LITRO_LANA_DE_VIDRIO_01_02_24.csv', index_col=0, parse_dates=True)


df3_0 = df3_0.rename_axis(index='Fecha')

df3_0 = df3_0.rename({'Tipo K, °C (SEN S/N: 21654195, LBL: T 3p)':'T_p3',
                'Tipo T, °C (SEN S/N: 21654195, LBL: T 3A)':'T_m3',
                'Tipo T, °C (SEN S/N: 21654195, LBL: T 3iv)':'T_vi3',
                'Tipo T, °C (SEN S/N: 21654195, LBL: T 3ev)':'T_ve3'
                  }, axis = 1)
# Out:
# C:\Users\USER.V\AppData\Local\Temp\ipykernel_16764\2543602072.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df3_0 = pd.read_csv('../data/001_raw/Cocina_3__1_LITRO_LANA_DE_VIDRIO_01_02_24.csv', index_col=0, parse_dates=True)

# %%
df3_0
# Out:
#                       T_p3   T_m3  T_vi3  T_ve3
# Fecha
# 2024-01-29 08:10:00  31.77  26.99  34.21  30.11
# 2024-01-29 08:11:00  31.92  27.06  34.34  30.20
# 2024-01-29 08:12:00  32.03  27.09  34.51  30.11
# 2024-01-29 08:13:00  32.20  27.22  34.67  30.17
# 2024-01-29 08:14:00  32.19  27.38  34.80  30.25
# ...                    ...    ...    ...    ...
# 2024-02-01 08:07:00  28.40  27.08  26.98  24.59
# 2024-02-01 08:08:00  28.47  27.09  26.93  24.52
# 2024-02-01 08:09:00  28.45  27.14  26.91  24.51
# 2024-02-01 08:10:00  28.47  27.16  26.94  24.54
# 2024-02-01 08:11:00  28.56  27.21  26.91  24.49
#
# [4322 rows x 4 columns]

# %%
h = '../data/001_raw/Cocina_3__SIN_AGUA_LANA_DE_VIDRIO_05_02_24.csv'

df3_1 = pd.read_csv(h, index_col = 0, parse_dates = True)
# renombrar el index
df3_1 = df3_1.rename_axis(index='Fecha')

df3_1 = df3_1.rename({'Tipo K, °C (SEN S/N: 21654195, LBL: T 3p)':'T_p3',
                'Tipo T, °C (SEN S/N: 21654195, LBL: T 3C)':'T_m3',
                'Tipo T, °C (SEN S/N: 21654195, LBL: T 3iv)':'T_vi3',
                'Tipo T, °C (SEN S/N: 21654195, LBL: T 3ev)':'T_ve3'
                  }, axis = 1)
# Out:
# C:\Users\USER.V\AppData\Local\Temp\ipykernel_16764\2853560225.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df3_1 = pd.read_csv(h, index_col = 0, parse_dates = True)

# %%
df3_1
# Out:
#                        T_p3   T_m3  T_vi3  T_ve3
# Fecha
# 2024-02-01 08:15:00   28.79  27.45  27.11  24.64
# 2024-02-01 08:16:00   28.84  27.45  27.09  24.63
# 2024-02-01 08:17:00   28.91  27.45  27.11  24.72
# 2024-02-01 08:18:00   29.00  27.47  27.21  24.73
# 2024-02-01 08:19:00   29.16  27.53  27.92  25.09
# ...                     ...    ...    ...    ...
# 2024-02-05 10:02:00  109.16  95.14  90.91  67.41
# 2024-02-05 10:03:00  109.64  95.82  91.17  66.30
# 2024-02-05 10:04:00  110.17  96.27  91.40  66.98
# 2024-02-05 10:05:00  110.61  97.01  91.55  66.55
# 2024-02-05 10:06:00  111.24  96.98  91.76  66.58
#
# [5872 rows x 4 columns]

# %% [markdown]
# <!-- ### Concatenar las cocinas 3 -->

# %%
df3 = pd.concat([df3_0, df3_1], axis = 0)
df3
# Out:
#                        T_p3   T_m3  T_vi3  T_ve3
# Fecha
# 2024-01-29 08:10:00   31.77  26.99  34.21  30.11
# 2024-01-29 08:11:00   31.92  27.06  34.34  30.20
# 2024-01-29 08:12:00   32.03  27.09  34.51  30.11
# 2024-01-29 08:13:00   32.20  27.22  34.67  30.17
# 2024-01-29 08:14:00   32.19  27.38  34.80  30.25
# ...                     ...    ...    ...    ...
# 2024-02-05 10:02:00  109.16  95.14  90.91  67.41
# 2024-02-05 10:03:00  109.64  95.82  91.17  66.30
# 2024-02-05 10:04:00  110.17  96.27  91.40  66.98
# 2024-02-05 10:05:00  110.61  97.01  91.55  66.55
# 2024-02-05 10:06:00  111.24  96.98  91.76  66.58
#
# [10194 rows x 4 columns]

# %%
df1.describe()
# Out:
#                T_p1          T_m1         T_vi1         T_ve1
# count  10186.000000  10186.000000  10186.000000  10186.000000
# mean      50.683955     43.378262     42.520877     34.316602
# std       39.938882     43.512302     31.684050     20.627280
# min       17.020000   -888.880000     15.500000     15.160000
# 25%       21.380000     15.157500     20.210000     19.940000
# 50%       27.730000     24.860000     23.895000     22.365000
# 75%       76.715000     68.580000     62.315000     47.982500
# max      153.510000    552.690000    117.150000     88.370000

# %%
df2.describe()
# Out:
#                T_p2          T_m2         T_vi2         T_ve2
# count  10190.000000  10190.000000  10190.000000  10190.000000
# mean      48.990342     44.098044     41.164921     34.519645
# std       36.212812     29.383193     28.758369     20.164962
# min       17.160000     16.890000     15.580000     15.420000
# 25%       21.600000     21.470000     20.320000     20.070000
# 50%       28.170000     27.230000     24.155000     22.720000
# 75%       76.252500     67.102500     61.055000     49.735000
# max      137.720000    117.850000    106.070000    157.640000

# %%
df3.describe()
# Out:
#                T_p3          T_m3         T_vi3         T_ve3
# count  10194.000000  10194.000000  10194.000000  10194.000000
# mean      49.756131     45.548516     42.357559     34.421152
# std       35.630408     29.843690     28.770402     19.114482
# min       17.170000     16.940000     15.620000     15.350000
# 25%       22.010000     21.942500     20.720000     20.280000
# 50%       30.105000     29.300000     25.590000     23.300000
# 75%       76.400000     68.067500     65.420000     50.370000
# max      139.880000    121.910000    111.050000     81.250000

# %% [markdown]
# # Importando estacion Hobo

# %%
estacion_hobo = pd.read_csv('../data/002_processed/001_estacion_hobo/estacion_hobo.csv', index_col = 0, parse_dates = True)
hobo = estacion_hobo[['To','Ig','WS']]
hobo
# Out:
#                           To     Ig    WS
# tiempo
# 2023-12-21 12:30:00  27.0380  990.6  0.00
# 2023-12-21 12:31:00  27.0085  988.1  0.67
# 2023-12-21 12:32:00  27.3195  990.6  0.67
# 2023-12-21 12:33:00  27.4375  990.6  1.00
# 2023-12-21 12:34:00  27.4589  989.4  0.67
# ...                      ...    ...   ...
# 2024-02-05 10:05:00  28.5582  786.9  0.67
# 2024-02-05 10:06:00  28.6842  789.4  1.00
# 2024-02-05 10:07:00  28.7244  793.1  1.00
# 2024-02-05 10:08:00  28.8263  795.6  1.00
# 2024-02-05 10:09:00  28.9630  799.4  0.67
#
# [66067 rows x 3 columns]

# %% [markdown]
# # Concatenando las tres cocinas sin agua con lana de vidrio

# %%
lanvidrio_SA = pd.concat([df1, df2, df3, hobo], axis = 1)
lanvidrio_SA
# Out:
#                      T_p1  T_m1  T_vi1  T_ve1  T_p2  T_m2  T_vi2  T_ve2  \
# 2023-12-21 12:30:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 2023-12-21 12:31:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 2023-12-21 12:32:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 2023-12-21 12:33:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 2023-12-21 12:34:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN
# ...                   ...   ...    ...    ...   ...   ...    ...    ...
# 2024-02-05 10:05:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 2024-02-05 10:06:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 2024-02-05 10:07:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 2024-02-05 10:08:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 2024-02-05 10:09:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN
#
#                        T_p3   T_m3  T_vi3  T_ve3       To     Ig    WS
# ...

# %%
## Eliminando valores fuera del rango

lanvidrio_SA.loc[lanvidrio_SA.T_m1 > 150, 'T_m1'] = float('NaN')
lanvidrio_SA.loc[lanvidrio_SA.T_m1 < 0, 'T_m1'] = float('NaN')
# lanvidrio_SA.loc[lanvidrio_SA.T_m1 == 547.61, 'T_m1'] = float('NaN')
# lanvidrio_SA.loc[lanvidrio_SA.T_m1 == 538.18, 'T_m1'] = float('NaN')
# lanvidrio_SA.loc[lanvidrio_SA.T_m1 == 528.71, 'T_m1'] = float('NaN')


# lanoveja_2l.loc[lanoveja_2l.T_p3 <= 0, 'T_p3'] = float('NaN')

# %%
lanvidrio_SA.max()
# Out:
# T_p1      153.5100
# T_m1      135.6700
# T_vi1     117.1500
# T_ve1      88.3700
# T_p2      137.7200
# T_m2      117.8500
# T_vi2     106.0700
# T_ve2     157.6400
# T_p3      139.8800
# T_m3      121.9100
# T_vi3     111.0500
# T_ve3      81.2500
# To         33.2552
# Ig       1276.9000
# WS          2.6700
# dtype: float64

# %%
lanvidrio_SA
# Out:
#                      T_p1  T_m1  T_vi1  T_ve1  T_p2  T_m2  T_vi2  T_ve2  \
# 2023-12-21 12:30:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 2023-12-21 12:31:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 2023-12-21 12:32:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 2023-12-21 12:33:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 2023-12-21 12:34:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN
# ...                   ...   ...    ...    ...   ...   ...    ...    ...
# 2024-02-05 10:05:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 2024-02-05 10:06:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 2024-02-05 10:07:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 2024-02-05 10:08:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 2024-02-05 10:09:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN
#
#                        T_p3   T_m3  T_vi3  T_ve3       To     Ig    WS
# ...

# %%
lanvidrio_SA = lanvidrio_SA.loc['2024-02-01 00:00:00':'2024-02-04 23:59:00']
lanvidrio_SA
# Out:
#                       T_p1   T_m1  T_vi1  T_ve1   T_p2   T_m2  T_vi2  T_ve2  \
# 2024-02-01 00:00:00  23.11  23.59  21.03  20.56  23.52  24.40  21.38  20.93
# 2024-02-01 00:01:00  23.09  23.56  21.03  20.53  23.56  24.36  21.41  20.91
# 2024-02-01 00:02:00  23.03  23.59  21.11  20.55  23.54  24.35  21.37  20.93
# 2024-02-01 00:03:00  23.04  23.55  21.10  20.54  23.49  24.33  21.37  20.90
# 2024-02-01 00:04:00  23.02  23.57  20.97  20.49  23.43  24.37  21.35  20.85
# ...                    ...    ...    ...    ...    ...    ...    ...    ...
# 2024-02-04 23:55:00  21.74  10.95  20.39  20.19  21.93  21.62  20.54  20.43
# 2024-02-04 23:56:00  21.74  10.74  20.37  20.19  21.94  21.60  20.56  20.43
# 2024-02-04 23:57:00  21.78  10.85  20.37  20.19  21.94  21.62  20.60  20.38
# 2024-02-04 23:58:00  21.70  10.83  20.38  20.17  21.90  21.58  20.62  20.48
# 2024-02-04 23:59:00  21.72  10.78  20.36  20.22  21.92  21.66  20.61  20.43
#
# ...

# %%
lanvidrio_SA[['T_p1','T_p2','T_p3']].plot()
# Out:
# <Axes: >

# %%
lanvidrio_SA[['T_m1','T_m2','T_m3']].plot()
# Out:
# <Axes: >

# %%
lanvidrio_SA[['T_vi1','T_vi2','T_vi3']].plot()
# Out:
# <Axes: >

# %%
lanvidrio_SA[['T_ve1','T_ve2','T_ve3']].plot()
# Out:
# <Axes: >

# %%
lanvidrio_SA.plot(figsize = (20,10))
# Out:
# <Axes: >

# %%
lanvidrio_SA.plot(subplots = True, figsize = (10,30))
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
lanvidrio_SA.max()
# Out:
# T_p1      153.5100
# T_m1      131.3000
# T_vi1     117.1500
# T_ve1      88.3700
# T_p2      137.7200
# T_m2      117.8500
# T_vi2     106.0700
# T_ve2      83.8600
# T_p3      139.8800
# T_m3      121.9100
# T_vi3     111.0500
# T_ve3      81.2500
# To         33.2552
# Ig       1145.6000
# WS          2.3400
# dtype: float64

# %%
lanvidrio_SA[['T_p1','T_m1','T_vi1','T_ve1','T_p2','T_m2','T_vi2','T_ve2','T_p3','T_m3','T_vi3','T_ve3','To']].plot(figsize = (20,10))
# Out:
# <Axes: >

# %% [markdown]
# # Exportar datos a excel

# %%
# dias 01, 02, 03 y 04 de febrero del 2024

# %%
#COCINA 1
lanvidrio_SA[['T_p1','T_m1','T_vi1','T_ve1','To','Ig','WS']].loc['2024-02-01 00:00:00':'2024-02-01 23:59:00'].to_excel('../data/002_processed/004_lana_vidrio/C1_LANVIDRIO_SA_dia1.xlsx')
lanvidrio_SA[['T_p1','T_m1','T_vi1','T_ve1','To','Ig','WS']].loc['2024-02-02 00:00:00':'2024-02-02 23:59:00'].to_excel('../data/002_processed/004_lana_vidrio/C1_LANVIDRIO_SA_dia2.xlsx')
lanvidrio_SA[['T_p1','T_m1','T_vi1','T_ve1','To','Ig','WS']].loc['2024-02-03 00:00:00':'2024-02-03 23:59:00'].to_excel('../data/002_processed/004_lana_vidrio/C1_LANVIDRIO_SA_dia3.xlsx')
lanvidrio_SA[['T_p1','T_m1','T_vi1','T_ve1','To','Ig','WS']].loc['2024-02-04 00:00:00':'2024-02-04 23:59:00'].to_excel('../data/002_processed/004_lana_vidrio/C1_LANVIDRIO_SA_dia4.xlsx')


#COCINA 2
lanvidrio_SA[['T_p2','T_m2','T_vi2','T_ve2','To','Ig','WS']].loc['2024-02-01 00:00:00':'2024-02-01 23:59:00'].to_excel('../data/002_processed/004_lana_vidrio/C2_LANVIDRIO_SA_dia1.xlsx')
lanvidrio_SA[['T_p2','T_m2','T_vi2','T_ve2','To','Ig','WS']].loc['2024-02-02 00:00:00':'2024-02-02 23:59:00'].to_excel('../data/002_processed/004_lana_vidrio/C2_LANVIDRIO_SA_dia2.xlsx')
lanvidrio_SA[['T_p2','T_m2','T_vi2','T_ve2','To','Ig','WS']].loc['2024-02-03 00:00:00':'2024-02-03 23:59:00'].to_excel('../data/002_processed/004_lana_vidrio/C2_LANVIDRIO_SA_dia3.xlsx')
lanvidrio_SA[['T_p2','T_m2','T_vi2','T_ve2','To','Ig','WS']].loc['2024-02-04 00:00:00':'2024-02-04 23:59:00'].to_excel('../data/002_processed/004_lana_vidrio/C2_LANVIDRIO_SA_dia4.xlsx')


#COCINA 3
lanvidrio_SA[['T_p3','T_m3','T_vi3','T_ve3','To','Ig','WS']].loc['2024-02-01 00:00:00':'2024-02-01 23:59:00'].to_excel('../data/002_processed/004_lana_vidrio/C3_LANVIDRIO_SA_dia1.xlsx')
lanvidrio_SA[['T_p3','T_m3','T_vi3','T_ve3','To','Ig','WS']].loc['2024-02-02 00:00:00':'2024-02-02 23:59:00'].to_excel('../data/002_processed/004_lana_vidrio/C3_LANVIDRIO_SA_dia2.xlsx')
lanvidrio_SA[['T_p3','T_m3','T_vi3','T_ve3','To','Ig','WS']].loc['2024-02-03 00:00:00':'2024-02-03 23:59:00'].to_excel('../data/002_processed/004_lana_vidrio/C3_LANVIDRIO_SA_dia3.xlsx')
lanvidrio_SA[['T_p3','T_m3','T_vi3','T_ve3','To','Ig','WS']].loc['2024-02-04 00:00:00':'2024-02-04 23:59:00'].to_excel('../data/002_processed/004_lana_vidrio/C3_LANVIDRIO_SA_dia4.xlsx')

# %% [markdown]
# ## Exportar toda la data

# %%
lanvidrio_SA.to_csv('../data/002_processed/005_completo/LANA_VIDRIO_SA.csv')
