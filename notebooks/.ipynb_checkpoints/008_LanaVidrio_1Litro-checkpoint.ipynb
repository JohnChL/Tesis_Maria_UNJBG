# %% [markdown]
# # Cocinas_Lana de vidrio_ 1 litros

# %%
import pandas as pd

# %% [markdown]
# ## cocina 1

# %%
# Importar dato faltante
# El data frame faltante se asigna con la variable "df1_0"

# %%
df1_0 = pd.read_csv('../data/001_raw/Cocina_1__2LITROS_LANA__DE_VIDRIO__29_01_24.csv', index_col=0, parse_dates=True)


df1_0 = df1_0.rename_axis(index='Fecha')

df1_0 = df1_0.rename({'Tipo K, °C (SEN S/N: 21654196, LBL: T 1p)':'T_p1',
                'Tipo T, °C (SEN S/N: 21654196, LBL: T 1a)':'T_m1',
                'Tipo K, °C (SEN S/N: 21654196, LBL: T 1 iv)':'T_vi1',
                'Tipo K, °C (SEN S/N: 21654196, LBL: T  1 ev)':'T_ve1'
                  }, axis = 1)
# Out:
# C:\Users\USER.V\AppData\Local\Temp\ipykernel_13968\2303366254.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df1_0 = pd.read_csv('../data/001_raw/Cocina_1__2LITROS_LANA__DE_VIDRIO__29_01_24.csv', index_col=0, parse_dates=True)

# %%
df1_0
# Out:
#                        T_p1    T_m1  T_vi1  T_ve1
# Fecha
# 2024-01-25 14:00:00  109.32  110.68  87.91  65.01
# 2024-01-25 14:01:00  109.25  110.52  87.85  63.77
# 2024-01-25 14:02:00  109.14  110.38  87.77  64.88
# 2024-01-25 14:03:00  109.04  110.37  87.61  64.69
# 2024-01-25 14:04:00  109.00  110.23  87.57  63.68
# ...                     ...     ...    ...    ...
# 2024-01-29 07:51:00   29.29   25.28  29.49  26.54
# 2024-01-29 07:52:00   29.38   25.33  29.60  26.64
# 2024-01-29 07:53:00   29.40   25.35  29.71  26.69
# 2024-01-29 07:54:00   29.46   25.46  29.81  27.12
# 2024-01-29 07:55:00   29.82   25.76  30.09  27.00
#
# [5396 rows x 4 columns]

# %%
f = '../data/001_raw/Cocina_1__1_LITROS_LANA__DE_VIDRIO_01_02_24.csv'

df1_1 = pd.read_csv(f, index_col = 0, parse_dates = True)
# renombrar el index
df1_1 = df1_1.rename_axis(index='Fecha')

df1_1 = df1_1.rename({'Tipo K, °C (SEN S/N: 21654196, LBL: T 1p)':'T_p1',
                'Tipo T, °C (SEN S/N: 21654196, LBL: T 1a)':'T_m1',
                'Tipo K, °C (SEN S/N: 21654196, LBL: T 1 iv)':'T_vi1',
                'Tipo K, °C (SEN S/N: 21654196, LBL: T  1 ev)':'T_ve1'
                  }, axis = 1)
# Out:
# C:\Users\USER.V\AppData\Local\Temp\ipykernel_13968\2381396649.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df1_1 = pd.read_csv(f, index_col = 0, parse_dates = True)

# %%
df1_1
# Out:
#                       T_p1   T_m1  T_vi1  T_ve1
# Fecha
# 2024-01-29 08:10:00  31.90  26.64  32.48  28.75
# 2024-01-29 08:11:00  32.02  26.72  32.68  28.98
# 2024-01-29 08:12:00  32.23  26.83  32.84  29.02
# 2024-01-29 08:13:00  32.44  26.96  32.94  29.12
# 2024-01-29 08:14:00  32.59  27.01  33.00  29.11
# ...                    ...    ...    ...    ...
# 2024-02-01 08:03:00  27.85  27.04  25.79  23.31
# 2024-02-01 08:04:00  27.84  27.10  25.69  23.30
# 2024-02-01 08:05:00  27.86  27.06  25.59  23.25
# 2024-02-01 08:06:00  27.73  27.09  25.51  23.22
# 2024-02-01 08:07:00  27.56  27.04  25.69  23.58
#
# [4318 rows x 4 columns]

# %%
# df1_1.plot(subplots = True)

# %% [markdown]
# <!-- ### Concatenar cocinas 1 -->

# %%
df1 = pd.concat([df1_0, df1_1], axis = 0)
df1
# Out:
#                        T_p1    T_m1  T_vi1  T_ve1
# Fecha
# 2024-01-25 14:00:00  109.32  110.68  87.91  65.01
# 2024-01-25 14:01:00  109.25  110.52  87.85  63.77
# 2024-01-25 14:02:00  109.14  110.38  87.77  64.88
# 2024-01-25 14:03:00  109.04  110.37  87.61  64.69
# 2024-01-25 14:04:00  109.00  110.23  87.57  63.68
# ...                     ...     ...    ...    ...
# 2024-02-01 08:03:00   27.85   27.04  25.79  23.31
# 2024-02-01 08:04:00   27.84   27.10  25.69  23.30
# 2024-02-01 08:05:00   27.86   27.06  25.59  23.25
# 2024-02-01 08:06:00   27.73   27.09  25.51  23.22
# 2024-02-01 08:07:00   27.56   27.04  25.69  23.58
#
# [9714 rows x 4 columns]

# %% [markdown]
# ## cocina 2

# %%
# Importar dato faltante
# El data frame faltante se asigna con la variable "df2_0"

# %%
df2_0 = pd.read_csv('../data/001_raw/Cocina_2___2_LITRO__LANA_DE_VIDRIO_29_01_24..csv', index_col=0, parse_dates=True)


df2_0 = df2_0.rename_axis(index='Fecha')

df2_0 = df2_0.rename({'Tipo K, °C (SEN S/N: 20939342, LBL: T 2p)':'T_p2',
                'Tipo T, °C (SEN S/N: 20939342, LBL: T 2A)':'T_m2',
                'Tipo K, °C (SEN S/N: 20939342, LBL: T 2iv)':'T_vi2',
                'Tipo K, °C (SEN S/N: 20939342, LBL: T 2ev)':'T_ve2'
                  }, axis = 1)
# Out:
# C:\Users\USER.V\AppData\Local\Temp\ipykernel_13968\1636705632.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df2_0 = pd.read_csv('../data/001_raw/Cocina_2___2_LITRO__LANA_DE_VIDRIO_29_01_24..csv', index_col=0, parse_dates=True)

# %%
df2_0
# Out:
#                       T_p2   T_m2  T_vi2  T_ve2
# Fecha
# 2024-01-25 14:00:00  93.76  88.17  76.61  60.07
# 2024-01-25 14:01:00  93.70  88.13  76.53  59.28
# 2024-01-25 14:02:00  93.73  88.09  76.31  59.98
# 2024-01-25 14:03:00  93.87  88.20  76.17  60.22
# 2024-01-25 14:04:00  93.87  88.37  76.06  58.96
# ...                    ...    ...    ...    ...
# 2024-01-29 07:54:00  29.20  25.48  30.62  27.40
# 2024-01-29 07:55:00  29.20  25.57  30.72  27.45
# 2024-01-29 07:56:00  29.29  25.62  30.84  27.51
# 2024-01-29 07:57:00  29.47  25.65  30.90  27.65
# 2024-01-29 07:58:00  29.56  25.85  30.98  27.81
#
# [5399 rows x 4 columns]

# %%
g = '../data/001_raw/Cocina_2___1_LITRO__LANA_DE_VIDRIO_01_02_24..csv'

df2_1 = pd.read_csv(g, index_col = 0, parse_dates = True)
# renombrar el index
df2_1 = df2_1.rename_axis(index='Fecha')

df2_1 = df2_1.rename({'Tipo K, °C (SEN S/N: 20939342, LBL: T 2p)':'T_p2',
                'Tipo T, °C (SEN S/N: 20939342, LBL: T 2A)':'T_m2',
                'Tipo K, °C (SEN S/N: 20939342, LBL: T 2iv)':'T_vi2',
                'Tipo K, °C (SEN S/N: 20939342, LBL: T 2ev)':'T_ve2'
                  }, axis = 1)
# Out:
# C:\Users\USER.V\AppData\Local\Temp\ipykernel_13968\1089990351.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df2_1 = pd.read_csv(g, index_col = 0, parse_dates = True)

# %%
df2_1
# Out:
#                       T_p2   T_m2  T_vi2  T_ve2
# Fecha
# 2024-01-29 08:10:00  31.42  26.55  33.92  29.61
# 2024-01-29 08:11:00  31.53  26.72  34.00  29.74
# 2024-01-29 08:12:00  31.63  26.81  34.23  29.63
# 2024-01-29 08:13:00  31.81  26.91  34.39  29.63
# 2024-01-29 08:14:00  31.90  27.05  34.47  29.70
# ...                    ...    ...    ...    ...
# 2024-02-01 08:05:00  28.70  26.20  25.84  23.90
# 2024-02-01 08:06:00  28.71  26.22  25.78  23.92
# 2024-02-01 08:07:00  28.71  26.26  25.75  23.96
# 2024-02-01 08:08:00  28.72  26.29  25.76  23.95
# 2024-02-01 08:09:00  28.69  26.32  25.66  23.90
#
# [4320 rows x 4 columns]

# %% [markdown]
# <!-- ### Concatenar cocinas 2 -->

# %%
df2 = pd.concat([df2_0, df2_1], axis = 0)
df2
# Out:
#                       T_p2   T_m2  T_vi2  T_ve2
# Fecha
# 2024-01-25 14:00:00  93.76  88.17  76.61  60.07
# 2024-01-25 14:01:00  93.70  88.13  76.53  59.28
# 2024-01-25 14:02:00  93.73  88.09  76.31  59.98
# 2024-01-25 14:03:00  93.87  88.20  76.17  60.22
# 2024-01-25 14:04:00  93.87  88.37  76.06  58.96
# ...                    ...    ...    ...    ...
# 2024-02-01 08:05:00  28.70  26.20  25.84  23.90
# 2024-02-01 08:06:00  28.71  26.22  25.78  23.92
# 2024-02-01 08:07:00  28.71  26.26  25.75  23.96
# 2024-02-01 08:08:00  28.72  26.29  25.76  23.95
# 2024-02-01 08:09:00  28.69  26.32  25.66  23.90
#
# [9719 rows x 4 columns]

# %% [markdown]
# ## cocina 3

# %%
# Importar dato faltante
# El data frame faltante se asigna con la variable "df3_0"

# %%
df3_0 = pd.read_csv('../data/001_raw/Cocina_3__2_LITRO_LANA_DE_VIDRIO_29_01_24.csv', index_col=0, parse_dates=True)


df3_0 = df3_0.rename_axis(index='Fecha')

df3_0 = df3_0.rename({'Tipo K, °C (SEN S/N: 21654195, LBL: T 3p)':'T_p3',
                'Tipo T, °C (SEN S/N: 21654195, LBL: T 3A)':'T_m3',
                'Tipo T, °C (SEN S/N: 21654195, LBL: T 3iv)':'T_vi3',
                'Tipo T, °C (SEN S/N: 21654195, LBL: T 3ev)':'T_ve3'
                  }, axis = 1)
# Out:
# C:\Users\USER.V\AppData\Local\Temp\ipykernel_13968\1347997944.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df3_0 = pd.read_csv('../data/001_raw/Cocina_3__2_LITRO_LANA_DE_VIDRIO_29_01_24.csv', index_col=0, parse_dates=True)

# %%
df3_0
# Out:
#                       T_p3   T_m3  T_vi3  T_ve3
# Fecha
# 2024-01-25 14:00:00  87.77  83.19  75.99  57.71
# 2024-01-25 14:01:00  88.03  83.43  76.25  57.05
# 2024-01-25 14:02:00  88.15  83.63  76.39  57.60
# 2024-01-25 14:03:00  88.35  83.84  76.41  58.22
# 2024-01-25 14:04:00  88.50  83.99  76.12  57.04
# ...                    ...    ...    ...    ...
# 2024-01-29 07:56:00  29.70  26.01  31.01  27.76
# 2024-01-29 07:57:00  29.74  26.11  31.16  27.89
# 2024-01-29 07:58:00  29.89  26.14  31.28  28.15
# 2024-01-29 07:59:00  30.03  26.19  31.50  28.36
# 2024-01-29 08:00:00  30.13  26.26  31.68  28.43
#
# [5401 rows x 4 columns]

# %%
h = '../data/001_raw/Cocina_3__1_LITRO_LANA_DE_VIDRIO_01_02_24.csv'

df3_1 = pd.read_csv(h, index_col = 0, parse_dates = True)
# renombrar el index
df3_1 = df3_1.rename_axis(index='Fecha')

df3_1 = df3_1.rename({'Tipo K, °C (SEN S/N: 21654195, LBL: T 3p)':'T_p3',
                'Tipo T, °C (SEN S/N: 21654195, LBL: T 3A)':'T_m3',
                'Tipo T, °C (SEN S/N: 21654195, LBL: T 3iv)':'T_vi3',
                'Tipo T, °C (SEN S/N: 21654195, LBL: T 3ev)':'T_ve3'
                  }, axis = 1)
# Out:
# C:\Users\USER.V\AppData\Local\Temp\ipykernel_13968\540794588.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df3_1 = pd.read_csv(h, index_col = 0, parse_dates = True)

# %%
df3_1
# Out:
#                       T_p3   T_m3  T_vi3  T_ve3
# Fecha
# 2024-01-29 08:10:00  31.77  26.99  34.21  30.11
# 2024-01-29 08:11:00  31.92  27.06  34.34  30.20
# 2024-01-29 08:12:00  32.03  27.09  34.51  30.11
# 2024-01-29 08:13:00  32.20  27.22  34.67  30.17
# 2024-01-29 08:14:00  32.19  27.38  34.80  30.25
# ...                    ...    ...    ...    ...
# 2024-02-01 08:07:00  28.40  27.08  26.98  24.59
# 2024-02-01 08:08:00  28.47  27.09  26.93  24.52
# 2024-02-01 08:09:00  28.45  27.14  26.91  24.51
# 2024-02-01 08:10:00  28.47  27.16  26.94  24.54
# 2024-02-01 08:11:00  28.56  27.21  26.91  24.49
#
# [4322 rows x 4 columns]

# %% [markdown]
# <!-- ### Concatenar las cocinas 3 -->

# %%
df3 = pd.concat([df3_0, df3_1], axis = 0)
df3
# Out:
#                       T_p3   T_m3  T_vi3  T_ve3
# Fecha
# 2024-01-25 14:00:00  87.77  83.19  75.99  57.71
# 2024-01-25 14:01:00  88.03  83.43  76.25  57.05
# 2024-01-25 14:02:00  88.15  83.63  76.39  57.60
# 2024-01-25 14:03:00  88.35  83.84  76.41  58.22
# 2024-01-25 14:04:00  88.50  83.99  76.12  57.04
# ...                    ...    ...    ...    ...
# 2024-02-01 08:07:00  28.40  27.08  26.98  24.59
# 2024-02-01 08:08:00  28.47  27.09  26.93  24.52
# 2024-02-01 08:09:00  28.45  27.14  26.91  24.51
# 2024-02-01 08:10:00  28.47  27.16  26.94  24.54
# 2024-02-01 08:11:00  28.56  27.21  26.91  24.49
#
# [9723 rows x 4 columns]

# %%
df1.describe()
# Out:
#               T_p1         T_m1        T_vi1        T_ve1
# count  9714.000000  9714.000000  9714.000000  9714.000000
# mean     46.263171    45.124984    41.289941    33.391109
# std      31.376012    30.666094    29.495323    19.061639
# min      17.020000    17.210000    15.500000    15.160000
# 25%      22.380000    22.622500    20.552500    19.780000
# 50%      29.100000    29.915000    24.740000    22.760000
# 75%      67.620000    66.192500    58.117500    45.290000
# max     120.740000   538.180000   113.440000    82.200000

# %%
df2.describe()
# Out:
#               T_p2         T_m2        T_vi2        T_ve2
# count  9719.000000  9719.000000  9719.000000  9719.000000
# mean     45.762821    43.232202    40.850974    33.494150
# std      30.019002    25.149557    27.426037    18.584576
# min      17.420000    17.620000    15.580000    15.420000
# 25%      22.950000    23.280000    21.010000    20.095000
# 50%      29.670000    30.500000    25.960000    23.360000
# 75%      65.675000    62.670000    56.515000    44.940000
# max     113.340000    97.120000   107.610000    78.320000

# %%
df3.describe()
# Out:
#               T_p3         T_m3        T_vi3        T_ve3
# count  9723.000000  9723.000000  9723.000000  9723.000000
# mean     45.062487    42.988814    39.910283    33.120676
# std      26.587840    22.984715    25.050690    17.231458
# min      17.350000    17.410000    15.620000    15.350000
# 25%      23.870000    24.400000    21.270000    20.430000
# 50%      32.100000    32.360000    26.490000    23.870000
# 75%      65.045000    62.415000    56.685000    45.145000
# max     101.870000    96.090000    98.100000    74.190000

# %% [markdown]
# # Importando estacion Hobo

# %%
estacion_hobo = pd.read_csv('../data/002_processed/001_estacion_hobo/estacion_hobo.csv', index_col = 0, parse_dates = True)
hobo = estacion_hobo[['To','Ig','WS']]
hobo
# Out:
#                           To     Ig    WS
# tiempo
# 2023-12-21 12:30:00  27.0380  990.6  0.00
# 2023-12-21 12:31:00  27.0085  988.1  0.67
# 2023-12-21 12:32:00  27.3195  990.6  0.67
# 2023-12-21 12:33:00  27.4375  990.6  1.00
# 2023-12-21 12:34:00  27.4589  989.4  0.67
# ...                      ...    ...   ...
# 2024-02-05 10:05:00  28.5582  786.9  0.67
# 2024-02-05 10:06:00  28.6842  789.4  1.00
# 2024-02-05 10:07:00  28.7244  793.1  1.00
# 2024-02-05 10:08:00  28.8263  795.6  1.00
# 2024-02-05 10:09:00  28.9630  799.4  0.67
#
# [66067 rows x 3 columns]

# %% [markdown]
# # Concatenando las tres cocinas 1L de agua con tecnopor

# %%
lanvidrio_1l = pd.concat([df1, df2, df3, hobo], axis = 1)
lanvidrio_1l
# Out:
#                      T_p1  T_m1  T_vi1  T_ve1  T_p2  T_m2  T_vi2  T_ve2  T_p3  \
# 2023-12-21 12:30:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN
# 2023-12-21 12:31:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN
# 2023-12-21 12:32:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN
# 2023-12-21 12:33:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN
# 2023-12-21 12:34:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN
# ...                   ...   ...    ...    ...   ...   ...    ...    ...   ...
# 2024-02-05 10:05:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN
# 2024-02-05 10:06:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN
# 2024-02-05 10:07:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN
# 2024-02-05 10:08:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN
# 2024-02-05 10:09:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN
#
#                      T_m3  T_vi3  T_ve3       To     Ig    WS
# 2023-12-21 12:30:00   NaN    NaN    NaN  27.0380  990.6  0.00
# 2023-12-21 12:31:00   NaN    NaN    NaN  27.0085  988.1  0.67
# 2023-12-21 12:32:00   NaN    NaN    NaN  27.3195  990.6  0.67
# 2023-12-21 12:33:00   NaN    NaN    NaN  27.4375  990.6  1.00
# 2023-12-21 12:34:00   NaN    NaN    NaN  27.4589  989.4  0.67
# ...                   ...    ...    ...      ...    ...   ...
# 2024-02-05 10:05:00   NaN    NaN    NaN  28.5582  786.9  0.67
# 2024-02-05 10:06:00   NaN    NaN    NaN  28.6842  789.4  1.00
# 2024-02-05 10:07:00   NaN    NaN    NaN  28.7244  793.1  1.00
# 2024-02-05 10:08:00   NaN    NaN    NaN  28.8263  795.6  1.00
# 2024-02-05 10:09:00   NaN    NaN    NaN  28.9630  799.4  0.67
#
# [66084 rows x 15 columns]

# %%
## Eliminando valores fuera del rango

lanvidrio_1l.loc[lanvidrio_1l.T_m1 == 538.18, 'T_m1'] = float('NaN')
lanvidrio_1l.loc[lanvidrio_1l.T_m1 == 423.39, 'T_m1'] = float('NaN')
lanvidrio_1l.loc[lanvidrio_1l.T_m1 == 101.57, 'T_m1'] = float('NaN')
lanvidrio_1l.loc[lanvidrio_1l.T_m1 == 99.84, 'T_m1'] = float('NaN')


# lanoveja_2l.loc[lanoveja_2l.T_p3 <= 0, 'T_p3'] = float('NaN')

# %%
lanvidrio_1l.max()
# Out:
# T_p1      120.7400
# T_m1       99.2900
# T_vi1     113.4400
# T_ve1      82.2000
# T_p2      113.3400
# T_m2       97.1200
# T_vi2     104.1000
# T_ve2      78.3200
# T_p3      101.8700
# T_m3       96.0900
# T_vi3      98.1000
# T_ve3      74.1900
# To         31.2954
# Ig       1125.6000
# WS          2.0000
# dtype: float64

# %%
lanvidrio_1l
# Out:
#                       T_p1   T_m1  T_vi1  T_ve1   T_p2   T_m2  T_vi2  T_ve2  \
# 2024-01-29 00:00:00  25.24  27.32  22.26  21.29  26.45  28.24  22.77  21.85
# 2024-01-29 00:01:00  25.23  27.26  22.13  21.29  26.40  28.28  22.78  21.88
# 2024-01-29 00:02:00  25.20  27.26  22.14  21.33  26.33  28.15  22.75  21.92
# 2024-01-29 00:03:00  25.17  27.21  22.12  21.29  26.42  28.18  22.76  21.87
# 2024-01-29 00:04:00  25.16  27.16  22.13  21.24  26.32  28.15  22.71  21.78
# ...                    ...    ...    ...    ...    ...    ...    ...    ...
# 2024-01-31 23:55:00  23.19  23.70  21.06  20.65  23.56  24.49  21.47  20.99
# 2024-01-31 23:56:00  23.11  23.67  21.13  20.61  23.65  24.49  21.41  21.03
# 2024-01-31 23:57:00  23.11  23.67  21.04  20.60  23.62  24.43  21.40  20.97
# 2024-01-31 23:58:00  23.11  23.60  21.04  20.59  23.53  24.51  21.39  20.94
# 2024-01-31 23:59:00  23.10  23.63  21.06  20.57  23.55  24.49  21.44  20.89
#
#                       T_p3   T_m3  T_vi3  T_ve3       To   Ig    WS
# 2024-01-29 00:00:00  27.56  28.95  23.11  21.85  20.0112  0.6  0.33
# 2024-01-29 00:01:00  27.51  28.97  23.14  21.88  20.0219  0.6  0.00
# 2024-01-29 00:02:00  27.52  28.93  23.15  21.90  20.0299  0.6  0.00
# 2024-01-29 00:03:00  27.48  28.89  23.13  21.83  20.0246  0.6  0.33
# 2024-01-29 00:04:00  27.47  28.87  23.08  21.80  19.9897  0.6  0.33
# ...                    ...    ...    ...    ...      ...  ...   ...
# 2024-01-31 23:55:00  24.09  26.17  21.86  21.16  20.4562  0.6  0.00
# 2024-01-31 23:56:00  24.05  26.13  21.86  21.18  20.4508  0.6  0.33
# 2024-01-31 23:57:00  24.04  26.11  21.86  21.19  20.4294  0.6  0.33
# 2024-01-31 23:58:00  24.03  26.09  21.83  21.16  20.4321  0.6  0.33
# 2024-01-31 23:59:00  23.99  26.06  21.80  21.13  20.4321  0.6  0.00
#
# [4320 rows x 15 columns]

# %%
lanvidrio_1l = lanvidrio_1l.loc['2024-01-29 00:00:00':'2024-01-31 23:59:00']
lanvidrio_1l
# Out:
#                       T_p1   T_m1  T_vi1  T_ve1   T_p2   T_m2  T_vi2  T_ve2  \
# 2024-01-29 00:00:00  25.24  27.32  22.26  21.29  26.45  28.24  22.77  21.85
# 2024-01-29 00:01:00  25.23  27.26  22.13  21.29  26.40  28.28  22.78  21.88
# 2024-01-29 00:02:00  25.20  27.26  22.14  21.33  26.33  28.15  22.75  21.92
# 2024-01-29 00:03:00  25.17  27.21  22.12  21.29  26.42  28.18  22.76  21.87
# 2024-01-29 00:04:00  25.16  27.16  22.13  21.24  26.32  28.15  22.71  21.78
# ...                    ...    ...    ...    ...    ...    ...    ...    ...
# 2024-01-31 23:55:00  23.19  23.70  21.06  20.65  23.56  24.49  21.47  20.99
# 2024-01-31 23:56:00  23.11  23.67  21.13  20.61  23.65  24.49  21.41  21.03
# 2024-01-31 23:57:00  23.11  23.67  21.04  20.60  23.62  24.43  21.40  20.97
# 2024-01-31 23:58:00  23.11  23.60  21.04  20.59  23.53  24.51  21.39  20.94
# 2024-01-31 23:59:00  23.10  23.63  21.06  20.57  23.55  24.49  21.44  20.89
#
#                       T_p3   T_m3  T_vi3  T_ve3       To   Ig    WS
# 2024-01-29 00:00:00  27.56  28.95  23.11  21.85  20.0112  0.6  0.33
# 2024-01-29 00:01:00  27.51  28.97  23.14  21.88  20.0219  0.6  0.00
# 2024-01-29 00:02:00  27.52  28.93  23.15  21.90  20.0299  0.6  0.00
# 2024-01-29 00:03:00  27.48  28.89  23.13  21.83  20.0246  0.6  0.33
# 2024-01-29 00:04:00  27.47  28.87  23.08  21.80  19.9897  0.6  0.33
# ...                    ...    ...    ...    ...      ...  ...   ...
# 2024-01-31 23:55:00  24.09  26.17  21.86  21.16  20.4562  0.6  0.00
# 2024-01-31 23:56:00  24.05  26.13  21.86  21.18  20.4508  0.6  0.33
# 2024-01-31 23:57:00  24.04  26.11  21.86  21.19  20.4294  0.6  0.33
# 2024-01-31 23:58:00  24.03  26.09  21.83  21.16  20.4321  0.6  0.33
# 2024-01-31 23:59:00  23.99  26.06  21.80  21.13  20.4321  0.6  0.00
#
# [4320 rows x 15 columns]

# %%
lanvidrio_1l[['T_p1','T_p2','T_p3']].plot()
# Out:
# <Axes: >

# %%
lanvidrio_1l[['T_m1','T_m2','T_m3']].plot()
# Out:
# <Axes: >

# %%
lanvidrio_1l[['T_vi1','T_vi2','T_vi3']].plot()
# Out:
# <Axes: >

# %%
lanvidrio_1l[['T_ve1','T_ve2','T_ve3']].plot()
# Out:
# <Axes: >

# %%
lanvidrio_1l.plot(figsize = (20,10))
# Out:
# <Axes: >

# %%
lanvidrio_1l.plot(subplots = True, figsize = (10,30))
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
lanvidrio_1l.max()
# Out:
# T_p1      120.7400
# T_m1       99.2900
# T_vi1     113.4400
# T_ve1      82.2000
# T_p2      113.3400
# T_m2       97.1200
# T_vi2     104.1000
# T_ve2      78.3200
# T_p3      101.8700
# T_m3       96.0900
# T_vi3      98.1000
# T_ve3      74.1900
# To         31.2954
# Ig       1125.6000
# WS          2.0000
# dtype: float64

# %%
lanvidrio_1l[['T_p1','T_m1','T_vi1','T_ve1','T_p2','T_m2','T_vi2','T_ve2','T_p3','T_m3','T_vi3','T_ve3','To']].plot(figsize = (20,10))
# Out:
# <Axes: >

# %% [markdown]
# # Exportar datos a excel

# %%
# dias 26, 27 y 28

# %%
#COCINA 1
# lanvidrio_2l[['T_p1','T_m1','T_vi1','T_ve1','To','Ig','WS']].loc['2024-01-26 00:00:00':'2024-01-26 23:59:00'].to_excel('../data/002_processed/004_lana_vidrio/C1_LANVIDRIO_2L_dia1.xlsx')
# lanvidrio_2l[['T_p1','T_m1','T_vi1','T_ve1','To','Ig','WS']].loc['2024-01-27 00:00:00':'2024-01-27 23:59:00'].to_excel('../data/002_processed/004_lana_vidrio/C1_LANVIDRIO_2L_dia2.xlsx')
# lanvidrio_2l[['T_p1','T_m1','T_vi1','T_ve1','To','Ig','WS']].loc['2024-01-28 00:00:00':'2024-01-28 23:59:00'].to_excel('../data/002_processed/004_lana_vidrio/C1_LANVIDRIO_2L_dia3.xlsx')

# #COCINA 2
# lanvidrio_2l[['T_p2','T_m2','T_vi2','T_ve2','To','Ig','WS']].loc['2024-01-26 00:00:00':'2024-01-26 23:59:00'].to_excel('../data/002_processed/004_lana_vidrio/C2_LANVIDRIO_2L_dia1.xlsx')
# lanvidrio_2l[['T_p2','T_m2','T_vi2','T_ve2','To','Ig','WS']].loc['2024-01-27 00:00:00':'2024-01-27 23:59:00'].to_excel('../data/002_processed/004_lana_vidrio/C2_LANVIDRIO_2L_dia2.xlsx')
# lanvidrio_2l[['T_p2','T_m2','T_vi2','T_ve2','To','Ig','WS']].loc['2024-01-28 00:00:00':'2024-01-28 23:59:00'].to_excel('../data/002_processed/004_lana_vidrio/C2_LANVIDRIO_2L_dia3.xlsx')

# #COCINA 3
# lanvidrio_2l[['T_p3','T_m3','T_vi3','T_ve3','To','Ig','WS']].loc['2024-01-26 00:00:00':'2024-01-26 23:59:00'].to_excel('../data/002_processed/004_lana_vidrio/C3_LANVIDRIO_2L_dia1.xlsx')
# lanvidrio_2l[['T_p3','T_m3','T_vi3','T_ve3','To','Ig','WS']].loc['2024-01-27 00:00:00':'2024-01-27 23:59:00'].to_excel('../data/002_processed/004_lana_vidrio/C3_LANVIDRIO_2L_dia2.xlsx')
# lanvidrio_2l[['T_p3','T_m3','T_vi3','T_ve3','To','Ig','WS']].loc['2024-01-28 00:00:00':'2024-01-28 23:59:00'].to_excel('../data/002_processed/004_lana_vidrio/C3_LANVIDRIO_2L_dia3.xlsx')

# %% [markdown]
# ## Exportar toda la data

# %%
# lanvidrio_2l.to_csv('../data/002_processed/005_completo/LANA_VIDRIO_2L.csv')
