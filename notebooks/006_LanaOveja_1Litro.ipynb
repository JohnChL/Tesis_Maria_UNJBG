# %% [markdown]
# # Cocinas_Lana de oveja_ 1 litro

# %%
import pandas as pd

# %% [markdown]
# ## cocina 1

# %%
# Importar dato faltante
# El data frame faltante se asigna con la variable "df1_0"

# %%
df1_0 = pd.read_csv('../data/001_raw/Cocina_1__2Litros_lana_de_oveja_21_01_24.csv', index_col=0, parse_dates=True)


df1_0 = df1_0.rename_axis(index='Fecha')

df1_0 = df1_0.rename({'Tipo K, °C (SEN S/N: 21654196, LBL: T 1p)':'T_p1',
                'Tipo T, °C (SEN S/N: 21654196, LBL: T 1a)':'T_m1',
                'Tipo K, °C (SEN S/N: 21654196, LBL: T 1 iv)':'T_vi1',
                'Tipo K, °C (SEN S/N: 21654196, LBL: T  1 ev)':'T_ve1'
                  }, axis = 1)
# Out:
# C:\Users\USER.V\AppData\Local\Temp\ipykernel_14760\4055229634.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df1_0 = pd.read_csv('../data/001_raw/Cocina_1__2Litros_lana_de_oveja_21_01_24.csv', index_col=0, parse_dates=True)

# %%
df1_0
# Out:
#                       T_p1   T_m1  T_vi1  T_ve1
# Fecha
# 2024-01-19 08:10:00  32.63  29.06  29.69  27.49
# 2024-01-19 08:11:00  32.74  29.17  29.78  27.64
# 2024-01-19 08:12:00  32.95  29.31  29.91  27.76
# 2024-01-19 08:13:00  33.16  29.47  29.96  27.80
# 2024-01-19 08:14:00  33.21  29.52  30.09  28.08
# ...                    ...    ...    ...    ...
# 2024-01-22 08:00:00  23.77  22.60  22.71  22.10
# 2024-01-22 08:01:00  23.84  22.59  22.74  22.13
# 2024-01-22 08:02:00  23.88  22.61  22.80  22.16
# 2024-01-22 08:03:00  23.79  22.63  22.80  22.11
# 2024-01-22 08:04:00  23.79  22.63  22.97  22.71
#
# [4315 rows x 4 columns]

# %%
f = '../data/001_raw/Cocina_1__1LITRO_lana_de_oveja_24_01_24.csv'

df1_1 = pd.read_csv(f, index_col = 0, parse_dates = True)
# renombrar el index
df1_1 = df1_1.rename_axis(index='Fecha')

df1_1 = df1_1.rename({'Tipo K, °C (SEN S/N: 21654196, LBL: T 1p)':'T_p1',
                'Tipo T, °C (SEN S/N: 21654196, LBL: T 1a)':'T_m1',
                'Tipo K, °C (SEN S/N: 21654196, LBL: T 1 iv)':'T_vi1',
                'Tipo K, °C (SEN S/N: 21654196, LBL: T  1 ev)':'T_ve1'
                  }, axis = 1)
# Out:
# C:\Users\USER.V\AppData\Local\Temp\ipykernel_14760\639958966.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df1_1 = pd.read_csv(f, index_col = 0, parse_dates = True)

# %%
# df1_1

# %%
# df1_1.plot(subplots = True)

# %% [markdown]
# ### Concatenar las cocinas 1

# %%
df1 = pd.concat([df1_0, df1_1], axis = 0)
df1
# Out:
#                       T_p1   T_m1  T_vi1  T_ve1
# Fecha
# 2024-01-19 08:10:00  32.63  29.06  29.69  27.49
# 2024-01-19 08:11:00  32.74  29.17  29.78  27.64
# 2024-01-19 08:12:00  32.95  29.31  29.91  27.76
# 2024-01-19 08:13:00  33.16  29.47  29.96  27.80
# 2024-01-19 08:14:00  33.21  29.52  30.09  28.08
# ...                    ...    ...    ...    ...
# 2024-01-25 09:10:00  56.68  60.29  55.46  48.96
# 2024-01-25 09:11:00  57.56  61.01  56.34  49.21
# 2024-01-25 09:12:00  58.23  61.74  56.99  50.06
# 2024-01-25 09:13:00  59.26  62.67  57.84  50.74
# 2024-01-25 09:14:00  59.97  63.44  58.58  50.61
#
# [8700 rows x 4 columns]

# %% [markdown]
# ## cocina 2

# %%
# Importar dato faltante
# El data frame faltante se asigna con la variable "df2_0"

# %%
df2_0 = pd.read_csv('../data/001_raw/Cocina2__2Litros__lana_oveja_21_01_24..csv', index_col=0, parse_dates=True)


df2_0 = df2_0.rename_axis(index='Fecha')

df2_0 = df2_0.rename({'Tipo K, °C (SEN S/N: 20939342, LBL: T 2p)':'T_p2',
                'Tipo T, °C (SEN S/N: 20939342, LBL: T 2A)':'T_m2',
                'Tipo K, °C (SEN S/N: 20939342, LBL: T 2iv)':'T_vi2',
                'Tipo K, °C (SEN S/N: 20939342, LBL: T 2ev)':'T_ve2'
                  }, axis = 1)
# Out:
# C:\Users\USER.V\AppData\Local\Temp\ipykernel_14760\4176631961.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df2_0 = pd.read_csv('../data/001_raw/Cocina2__2Litros__lana_oveja_21_01_24..csv', index_col=0, parse_dates=True)

# %%
df2_0
# Out:
#                       T_p2   T_m2  T_vi2  T_ve2
# Fecha
# 2024-01-19 08:10:00  30.49  27.95  29.99  28.35
# 2024-01-19 08:11:00  30.55  28.06  30.14  28.50
# 2024-01-19 08:12:00  30.74  28.21  30.16  28.65
# 2024-01-19 08:13:00  30.84  28.24  30.39  28.76
# 2024-01-19 08:14:00  30.96  28.42  30.44  28.81
# ...                    ...    ...    ...    ...
# 2024-01-22 08:02:00  24.30  23.28  23.43  22.88
# 2024-01-22 08:03:00  22.84  24.35  23.43  22.96
# 2024-01-22 08:04:00  24.42  23.27  23.41  23.04
# 2024-01-22 08:05:00  24.46  23.27  23.43  23.10
# 2024-01-22 08:06:00  24.49  23.30  23.43  23.10
#
# [4317 rows x 4 columns]

# %%
g = '../data/001_raw/Cocina2___1LITRO__lana_oveja24_01_24.csv'

df2_1 = pd.read_csv(g, index_col = 0, parse_dates = True)
# renombrar el index
df2_1 = df2_1.rename_axis(index='Fecha')

df2_1 = df2_1.rename({'Tipo K, °C (SEN S/N: 20939342, LBL: T 2p)':'T_p2',
                'Tipo T, °C (SEN S/N: 20939342, LBL: T 2A)':'T_m2',
                'Tipo K, °C (SEN S/N: 20939342, LBL: T 2iv)':'T_vi2',
                'Tipo K, °C (SEN S/N: 20939342, LBL: T 2ev)':'T_ve2'
                  }, axis = 1)
# Out:
# C:\Users\USER.V\AppData\Local\Temp\ipykernel_14760\3326103519.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df2_1 = pd.read_csv(g, index_col = 0, parse_dates = True)

# %%
# df2_1

# %% [markdown]
# ### Concatenar las cocinas 2

# %%
df2 = pd.concat([df2_0, df2_1], axis = 0)
df2
# Out:
#                       T_p2   T_m2  T_vi2  T_ve2
# Fecha
# 2024-01-19 08:10:00  30.49  27.95  29.99  28.35
# 2024-01-19 08:11:00  30.55  28.06  30.14  28.50
# 2024-01-19 08:12:00  30.74  28.21  30.16  28.65
# 2024-01-19 08:13:00  30.84  28.24  30.39  28.76
# 2024-01-19 08:14:00  30.96  28.42  30.44  28.81
# ...                    ...    ...    ...    ...
# 2024-01-25 09:15:00  68.29  71.40  62.83  56.76
# 2024-01-25 09:16:00  69.01  71.97  63.15  56.85
# 2024-01-25 09:17:00  69.61  72.66  63.61  57.81
# 2024-01-25 09:18:00  70.26  73.37  63.94  57.61
# 2024-01-25 09:19:00  70.96  73.98  64.43  57.15
#
# [8707 rows x 4 columns]

# %% [markdown]
# ## cocina 3

# %%
# Importar dato faltante
# El data frame faltante se asigna con la variable "df3_0"

# %%
df3_0 = pd.read_csv('../data/001_raw/Cocina_3__2Litros_lana_oveja_21_01_24.csv', index_col=0, parse_dates=True)


df3_0 = df3_0.rename_axis(index='Fecha')

df3_0 = df3_0.rename({'Tipo K, °C (SEN S/N: 21654195, LBL: T 3p)':'T_p3',
                'Tipo T, °C (SEN S/N: 21654195, LBL: T 3A)':'T_m3',
                'Tipo T, °C (SEN S/N: 21654195, LBL: T 3iv)':'T_vi3',
                'Tipo T, °C (SEN S/N: 21654195, LBL: T 3ev)':'T_ve3'
                  }, axis = 1)
# Out:
# C:\Users\USER.V\AppData\Local\Temp\ipykernel_14760\3885975975.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df3_0 = pd.read_csv('../data/001_raw/Cocina_3__2Litros_lana_oveja_21_01_24.csv', index_col=0, parse_dates=True)

# %%
df3_0
# Out:
#                       T_p3   T_m3  T_vi3  T_ve3
# Fecha
# 2024-01-19 08:10:00  30.71  26.46  31.50  28.44
# 2024-01-19 08:11:00  30.83  26.54  31.61  28.56
# 2024-01-19 08:12:00  30.96  26.63  31.74  28.72
# 2024-01-19 08:13:00  31.09  26.71  31.91  28.79
# 2024-01-19 08:14:00  31.23  26.78  32.01  28.76
# ...                    ...    ...    ...    ...
# 2024-01-22 08:03:00  24.62  23.56  23.93  23.17
# 2024-01-22 08:04:00  24.69  23.60  23.98  23.21
# 2024-01-22 08:05:00  24.67  23.57  24.01  23.24
# 2024-01-22 08:06:00  24.73  23.64  24.09  23.30
# 2024-01-22 08:07:00  24.75  23.63  24.10  23.31
#
# [4318 rows x 4 columns]

# %%
h = '../data/001_raw/Cocina_3__1_LITRO_lana_oveja_24_01_24.csv'

df3_1 = pd.read_csv(h, index_col = 0, parse_dates = True)
# renombrar el index
df3_1 = df3_1.rename_axis(index='Fecha')

df3_1 = df3_1.rename({'Tipo K, °C (SEN S/N: 21654195, LBL: T 3p)':'T_p3',
                'Tipo T, °C (SEN S/N: 21654195, LBL: T 3A)':'T_m3',
                'Tipo T, °C (SEN S/N: 21654195, LBL: T 3iv)':'T_vi3',
                'Tipo T, °C (SEN S/N: 21654195, LBL: T 3ev)':'T_ve3'
                  }, axis = 1)
# Out:
# C:\Users\USER.V\AppData\Local\Temp\ipykernel_14760\2445276399.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df3_1 = pd.read_csv(h, index_col = 0, parse_dates = True)

# %%
df3_1
# Out:
#                       T_p3   T_m3  T_vi3  T_ve3
# Fecha
# 2024-01-22 08:10:00  25.13  23.74  24.58  23.77
# 2024-01-22 08:11:00  25.23  23.69  25.40  24.50
# 2024-01-22 08:12:00  25.43  23.73  26.68  25.82
# 2024-01-22 08:13:00  25.60  23.75  27.92  26.96
# 2024-01-22 08:14:00  25.83  23.80  29.09  27.98
# ...                    ...    ...    ...    ...
# 2024-01-25 09:18:00  68.74  69.88  66.00  55.04
# 2024-01-25 09:19:00  69.41  70.45  66.40  53.89
# 2024-01-25 09:20:00  70.08  71.00  66.63  54.73
# 2024-01-25 09:21:00  70.61  71.56  66.99  55.38
# 2024-01-25 09:22:00  71.21  72.12  67.34  55.10
#
# [4393 rows x 4 columns]

# %% [markdown]
# ### Concatenar las cocinas 3

# %%
df3 = pd.concat([df3_0, df3_1], axis = 0)
df3
# Out:
#                       T_p3   T_m3  T_vi3  T_ve3
# Fecha
# 2024-01-19 08:10:00  30.71  26.46  31.50  28.44
# 2024-01-19 08:11:00  30.83  26.54  31.61  28.56
# 2024-01-19 08:12:00  30.96  26.63  31.74  28.72
# 2024-01-19 08:13:00  31.09  26.71  31.91  28.79
# 2024-01-19 08:14:00  31.23  26.78  32.01  28.76
# ...                    ...    ...    ...    ...
# 2024-01-25 09:18:00  68.74  69.88  66.00  55.04
# 2024-01-25 09:19:00  69.41  70.45  66.40  53.89
# 2024-01-25 09:20:00  70.08  71.00  66.63  54.73
# 2024-01-25 09:21:00  70.61  71.56  66.99  55.38
# 2024-01-25 09:22:00  71.21  72.12  67.34  55.10
#
# [8711 rows x 4 columns]

# %%
df1.describe()
# Out:
#               T_p1         T_m1        T_vi1        T_ve1
# count  8700.000000  8700.000000  8700.000000  8700.000000
# mean     48.950644    47.852357    41.945553    34.340209
# std      33.144236    35.502496    28.728501    19.547150
# min      17.160000    18.570000    16.960000    16.790000
# 25%      22.410000    23.110000    20.450000    19.580000
# 50%      31.490000    33.500000    25.940000    23.670000
# 75%      72.410000    70.415000    58.560000    46.095000
# max     122.670000   544.290000   110.600000    79.830000

# %%
df2.describe()
# Out:
#               T_p2         T_m2        T_vi2        T_ve2
# count  8707.000000  8707.000000  8707.000000  8707.000000
# mean     46.184757    44.982531    41.173426    34.503119
# std      32.885009    25.282807    26.483776    19.298982
# min    -888.880000    17.800000    16.600000    16.460000
# 25%      23.140000    23.420000    20.730000    19.760000
# 50%      33.490000    33.980000    26.710000    23.940000
# 75%      68.280000    65.025000    58.545000    47.490000
# max     107.400000    98.320000    99.440000    77.260000

# %%
df3.describe()
# Out:
#               T_p3         T_m3        T_vi3        T_ve3
# count  8711.000000  8711.000000  8711.000000  8711.000000
# mean     45.614993    45.073302    39.421322    33.756507
# std      25.600727    23.523470    22.884867    16.884761
# min      16.400000    18.930000    16.940000    16.790000
# 25%      23.470000    24.650000    21.040000    20.270000
# 50%      34.680000    35.260000    27.440000    24.890000
# 75%      66.605000    64.795000    56.905000    46.900000
# max     104.700000    98.110000    88.370000    70.870000

# %% [markdown]
# # Importando estacion Hobo

# %%
estacion_hobo = pd.read_csv('../data/002_processed/001_estacion_hobo/estacion_hobo.csv', index_col = 0, parse_dates = True)
hobo = estacion_hobo[['To','Ig','WS']]
hobo
# Out:
#                           To     Ig    WS
# tiempo
# 2023-12-21 12:30:00  27.0380  990.6  0.00
# 2023-12-21 12:31:00  27.0085  988.1  0.67
# 2023-12-21 12:32:00  27.3195  990.6  0.67
# 2023-12-21 12:33:00  27.4375  990.6  1.00
# 2023-12-21 12:34:00  27.4589  989.4  0.67
# ...                      ...    ...   ...
# 2024-02-05 10:05:00  28.5582  786.9  0.67
# 2024-02-05 10:06:00  28.6842  789.4  1.00
# 2024-02-05 10:07:00  28.7244  793.1  1.00
# 2024-02-05 10:08:00  28.8263  795.6  1.00
# 2024-02-05 10:09:00  28.9630  799.4  0.67
#
# [66067 rows x 3 columns]

# %% [markdown]
# # Concatenando las tres cocinas 1L de agua con lana de oveja

# %%
lanoveja_1l = pd.concat([df1, df2, df3, hobo], axis = 1)
lanoveja_1l
# Out:
#                      T_p1  T_m1  T_vi1  T_ve1  T_p2  T_m2  T_vi2  T_ve2  T_p3  \
# 2023-12-21 12:30:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN
# 2023-12-21 12:31:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN
# 2023-12-21 12:32:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN
# 2023-12-21 12:33:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN
# 2023-12-21 12:34:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN
# ...                   ...   ...    ...    ...   ...   ...    ...    ...   ...
# 2024-02-05 10:05:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN
# 2024-02-05 10:06:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN
# 2024-02-05 10:07:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN
# 2024-02-05 10:08:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN
# 2024-02-05 10:09:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN
#
#                      T_m3  T_vi3  T_ve3       To     Ig    WS
# 2023-12-21 12:30:00   NaN    NaN    NaN  27.0380  990.6  0.00
# 2023-12-21 12:31:00   NaN    NaN    NaN  27.0085  988.1  0.67
# 2023-12-21 12:32:00   NaN    NaN    NaN  27.3195  990.6  0.67
# 2023-12-21 12:33:00   NaN    NaN    NaN  27.4375  990.6  1.00
# 2023-12-21 12:34:00   NaN    NaN    NaN  27.4589  989.4  0.67
# ...                   ...    ...    ...      ...    ...   ...
# 2024-02-05 10:05:00   NaN    NaN    NaN  28.5582  786.9  0.67
# 2024-02-05 10:06:00   NaN    NaN    NaN  28.6842  789.4  1.00
# 2024-02-05 10:07:00   NaN    NaN    NaN  28.7244  793.1  1.00
# 2024-02-05 10:08:00   NaN    NaN    NaN  28.8263  795.6  1.00
# 2024-02-05 10:09:00   NaN    NaN    NaN  28.9630  799.4  0.67
#
# [66067 rows x 15 columns]

# %%
## Eliminando valores fuera del rango

lanoveja_1l.loc[lanoveja_1l.T_p2 == -888.88, 'T_p2'] = float('NaN')
lanoveja_1l.loc[lanoveja_1l.T_m1 == 544.29, 'T_m1'] = float('NaN')
lanoveja_1l.loc[lanoveja_1l.T_m1 == 538.18, 'T_m1'] = float('NaN')

# %%
lanoveja_1l
# Out:
#                      T_p1  T_m1  T_vi1  T_ve1  T_p2  T_m2  T_vi2  T_ve2  T_p3  \
# 2023-12-21 12:30:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN
# 2023-12-21 12:31:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN
# 2023-12-21 12:32:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN
# 2023-12-21 12:33:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN
# 2023-12-21 12:34:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN
# ...                   ...   ...    ...    ...   ...   ...    ...    ...   ...
# 2024-02-05 10:05:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN
# 2024-02-05 10:06:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN
# 2024-02-05 10:07:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN
# 2024-02-05 10:08:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN
# 2024-02-05 10:09:00   NaN   NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN
#
#                      T_m3  T_vi3  T_ve3       To     Ig    WS
# 2023-12-21 12:30:00   NaN    NaN    NaN  27.0380  990.6  0.00
# 2023-12-21 12:31:00   NaN    NaN    NaN  27.0085  988.1  0.67
# 2023-12-21 12:32:00   NaN    NaN    NaN  27.3195  990.6  0.67
# 2023-12-21 12:33:00   NaN    NaN    NaN  27.4375  990.6  1.00
# 2023-12-21 12:34:00   NaN    NaN    NaN  27.4589  989.4  0.67
# ...                   ...    ...    ...      ...    ...   ...
# 2024-02-05 10:05:00   NaN    NaN    NaN  28.5582  786.9  0.67
# 2024-02-05 10:06:00   NaN    NaN    NaN  28.6842  789.4  1.00
# 2024-02-05 10:07:00   NaN    NaN    NaN  28.7244  793.1  1.00
# 2024-02-05 10:08:00   NaN    NaN    NaN  28.8263  795.6  1.00
# 2024-02-05 10:09:00   NaN    NaN    NaN  28.9630  799.4  0.67
#
# [66067 rows x 15 columns]

# %%
lanoveja_1l.max()
# Out:
# T_p1      122.6700
# T_m1      101.5100
# T_vi1     110.6000
# T_ve1      79.8300
# T_p2      107.4000
# T_m2       98.3200
# T_vi2      99.4400
# T_ve2      77.2600
# T_p3      104.7000
# T_m3       98.1100
# T_vi3      88.3700
# T_ve3      70.8700
# To         33.2552
# Ig       1276.9000
# WS          2.6700
# dtype: float64

# %%
lanoveja_1l = lanoveja_1l.loc['2024-01-22 00:00:00':'2024-01-24 23:59:00']
lanoveja_1l
# Out:
#                       T_p1   T_m1  T_vi1  T_ve1   T_p2   T_m2  T_vi2  T_ve2  \
# 2024-01-22 00:00:00  26.25  28.42  21.85  20.22  28.44  30.49  22.67  20.75
# 2024-01-22 00:01:00  26.25  28.40  21.79  20.20  28.36  30.44  22.64  20.68
# 2024-01-22 00:02:00  26.20  28.43  21.74  20.18  28.34  30.45  22.59  20.63
# 2024-01-22 00:03:00  26.16  28.30  21.75  20.15  28.35  30.40  22.57  20.63
# 2024-01-22 00:04:00  26.14  28.30  21.69  20.14  28.33  30.39  22.56  20.57
# ...                    ...    ...    ...    ...    ...    ...    ...    ...
# 2024-01-24 23:55:00  23.54  23.96  21.65  21.21  24.92  25.44  22.25  21.43
# 2024-01-24 23:56:00  23.55  23.91  21.61  21.17  24.94  25.48  22.18  21.41
# 2024-01-24 23:57:00  23.51  23.93  21.63  21.15  24.87  25.42  22.20  21.45
# 2024-01-24 23:58:00  23.49  23.91  21.64  21.16  24.84  25.42  22.18  21.44
# 2024-01-24 23:59:00  23.51  23.89  21.61  21.16  24.77  25.33  22.23  21.40
#
#                       T_p3   T_m3  T_vi3  T_ve3       To   Ig    WS
# 2024-01-22 00:00:00  29.04  31.02  22.58  21.06  20.1988  0.6  0.00
# 2024-01-22 00:01:00  28.96  30.94  22.55  21.05  20.1854  0.6  0.00
# 2024-01-22 00:02:00  28.99  30.89  22.52  21.05  20.1693  0.6  0.00
# 2024-01-22 00:03:00  28.96  30.90  22.52  21.01  20.1586  0.6  0.33
# 2024-01-22 00:04:00  28.89  30.83  22.48  21.01  20.1452  0.6  0.67
# ...                    ...    ...    ...    ...      ...  ...   ...
# 2024-01-24 23:55:00  24.65  24.92  21.91  21.39  20.8155  0.6  0.00
# 2024-01-24 23:56:00  24.60  24.90  21.90  21.42  20.7806  0.6  0.00
# 2024-01-24 23:57:00  24.59  24.90  21.92  21.42  20.7645  0.6  0.33
# 2024-01-24 23:58:00  24.52  24.84  21.88  21.43  20.7726  0.6  0.00
# 2024-01-24 23:59:00  24.52  24.85  21.91  21.46  20.7994  0.6  0.33
#
# [4320 rows x 15 columns]

# %%
lanoveja_1l[['T_p1','T_p2','T_p3']].plot()
# Out:
# <Axes: >

# %%
lanoveja_1l[['T_m1','T_m2','T_m3']].plot()
# Out:
# <Axes: >

# %%
lanoveja_1l[['T_vi1','T_vi2','T_vi3']].plot()
# Out:
# <Axes: >

# %%
lanoveja_1l[['T_ve1','T_ve2','T_ve3']].plot()
# Out:
# <Axes: >

# %%
lanoveja_1l.plot(figsize = (20,10))
# Out:
# <Axes: >

# %%
lanoveja_1l.plot(subplots = True, figsize = (10,30))
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
lanoveja_1l.min()
# Out:
# T_p1     17.7000
# T_m1     18.5700
# T_vi1    16.9600
# T_ve1    16.7900
# T_p2     15.2800
# T_m2     17.8000
# T_vi2    16.6000
# T_ve2    16.4600
# T_p3     16.4000
# T_m3     18.9300
# T_vi3    16.9400
# T_ve3    16.7900
# To       19.0835
# Ig        0.6000
# WS        0.0000
# dtype: float64

# %%
lanoveja_1l[['T_p1','T_m1','T_vi1','T_ve1','T_p2','T_m2','T_vi2','T_ve2','T_p3','T_m3','T_vi3','T_ve3','To']].plot(figsize = (20,10))
# Out:
# <Axes: >

# %% [markdown]
# # Exportar datos a excel

# %%
# dias 22, 23 y 24

# %%
#COCINA 1
lanoveja_1l[['T_p1','T_m1','T_vi1','T_ve1','To','Ig','WS']].loc['2024-01-22 00:00:00':'2024-01-22 23:59:00'].to_excel('../data/002_processed/003_lana_oveja/C1_LANOVJ_1L_dia1.xlsx')
lanoveja_1l[['T_p1','T_m1','T_vi1','T_ve1','To','Ig','WS']].loc['2024-01-23 00:00:00':'2024-01-23 23:59:00'].to_excel('../data/002_processed/003_lana_oveja/C1_LANOVJ_1L_dia2.xlsx')
lanoveja_1l[['T_p1','T_m1','T_vi1','T_ve1','To','Ig','WS']].loc['2024-01-24 00:00:00':'2024-01-24 23:59:00'].to_excel('../data/002_processed/003_lana_oveja/C1_LANOVJ_1L_dia3.xlsx')

#COCINA 2
lanoveja_1l[['T_p2','T_m2','T_vi2','T_ve2','To','Ig','WS']].loc['2024-01-22 00:00:00':'2024-01-22 23:59:00'].to_excel('../data/002_processed/003_lana_oveja/C2_LANOVJ_1L_dia1.xlsx')
lanoveja_1l[['T_p2','T_m2','T_vi2','T_ve2','To','Ig','WS']].loc['2024-01-23 00:00:00':'2024-01-23 23:59:00'].to_excel('../data/002_processed/003_lana_oveja/C2_LANOVJ_1L_dia2.xlsx')
lanoveja_1l[['T_p2','T_m2','T_vi2','T_ve2','To','Ig','WS']].loc['2024-01-24 00:00:00':'2024-01-24 23:59:00'].to_excel('../data/002_processed/003_lana_oveja/C2_LANOVJ_1L_dia3.xlsx')

#COCINA 3
lanoveja_1l[['T_p3','T_m3','T_vi3','T_ve3','To','Ig','WS']].loc['2024-01-22 00:00:00':'2024-01-22 23:59:00'].to_excel('../data/002_processed/003_lana_oveja/C3_LANOVJ_1L_dia1.xlsx')
lanoveja_1l[['T_p3','T_m3','T_vi3','T_ve3','To','Ig','WS']].loc['2024-01-23 00:00:00':'2024-01-23 23:59:00'].to_excel('../data/002_processed/003_lana_oveja/C3_LANOVJ_1L_dia2.xlsx')
lanoveja_1l[['T_p3','T_m3','T_vi3','T_ve3','To','Ig','WS']].loc['2024-01-24 00:00:00':'2024-01-24 23:59:00'].to_excel('../data/002_processed/003_lana_oveja/C3_LANOVJ_1L_dia3.xlsx')

# %% [markdown]
# ## Exportar toda la data

# %%
lanoveja_1l.to_csv('../data/002_processed/005_completo/LANA_OVEJA_1L.csv')
