# %%
import pandas as pd

# %%
# cocina 1

# %%
f = '../data/001_raw/Cocina_1_sin_agua_lana_de_oveja_12_01_24.csv'

# %%
df1 = pd.read_csv(f, index_col = 0, parse_dates = True)
# renombrar el index
df1 = df1.rename_axis(index='Fecha')

df1 = df1.rename({'Tipo K, °C (SEN S/N: 21654196, LBL: T 1p)':'T_p1',
                'Tipo T, °C (SEN S/N: 21654196, LBL: T 1C)':'T_c1',
                'Tipo K, °C (SEN S/N: 21654196, LBL: T 1 iv)':'T_vi1',
                'Tipo K, °C (SEN S/N: 21654196, LBL: T  1 ev)':'T_ve1'
                  }, axis = 1)
# Out:
# C:\Users\USER.V\AppData\Local\Temp\ipykernel_524\441892326.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df1 = pd.read_csv(f, index_col = 0, parse_dates = True)

# %%
df1
# Out:
#                        T_p1   T_c1  T_vi1  T_ve1
# Fecha
# 2024-01-05 15:00:00  104.25  90.64  58.96  55.82
# 2024-01-05 15:01:00  103.74  89.97  57.51  55.55
# 2024-01-05 15:02:00  103.24  89.42  58.00  55.12
# 2024-01-05 15:03:00  102.74  89.65  57.65  55.79
# 2024-01-05 15:04:00  102.29  89.13  59.16  56.11
# ...                     ...    ...    ...    ...
# 2024-01-12 09:43:00   59.53  46.30  84.17  54.01
# 2024-01-12 09:44:00   60.11  47.18  83.84  54.25
# 2024-01-12 09:45:00   60.75  47.87  84.12  55.28
# 2024-01-12 09:46:00   61.38  48.69  84.66  55.85
# 2024-01-12 09:47:00   62.04  49.51  85.45  56.06
#
# [9768 rows x 4 columns]

# %%
df1.plot(subplots = True)
# Out:
# array([<Axes: xlabel='Fecha'>, <Axes: xlabel='Fecha'>,
#        <Axes: xlabel='Fecha'>, <Axes: xlabel='Fecha'>], dtype=object)

# %%
# cocina 2

# %%
g = '../data/001_raw/Cocina2__sin_agua__lana_oveja_12_01_24..csv'

df2 = pd.read_csv(g, index_col = 0, parse_dates = True)
# renombrar el index
df2 = df2.rename_axis(index='Fecha')

df2 = df2.rename({'Tipo K, °C (SEN S/N: 20939342, LBL: T 2p)':'T_p2',
                'Tipo T, °C (SEN S/N: 20939342, LBL: T 2C)':'T_c2',
                'Tipo K, °C (SEN S/N: 20939342, LBL: T 2iv)':'T_vi2',
                'Tipo K, °C (SEN S/N: 20939342, LBL: T 2ev)':'T_ve2'
                  }, axis = 1)
# Out:
# C:\Users\USER.V\AppData\Local\Temp\ipykernel_524\2810588192.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df2 = pd.read_csv(g, index_col = 0, parse_dates = True)

# %%
df2
# Out:
#                        T_p2   T_c2  T_vi2  T_ve2
# Fecha
# 2024-01-05 15:00:00 -888.88  78.06  63.84  48.38
# 2024-01-05 15:01:00 -888.88  76.85  63.49  48.11
# 2024-01-05 15:02:00 -888.88  75.19  63.18  47.74
# 2024-01-05 15:03:00 -888.88  76.95  62.95  48.33
# 2024-01-05 15:04:00 -888.88  76.73  62.73  48.36
# ...                     ...    ...    ...    ...
# 2024-01-12 09:40:00   62.39  38.29  64.80  55.75
# 2024-01-12 09:41:00   62.69  39.13  65.39  55.28
# 2024-01-12 09:42:00   63.14  39.96  65.88  55.55
# 2024-01-12 09:43:00   63.48  40.73  66.35  55.73
# 2024-01-12 09:44:00   63.91  41.44  66.83  55.82
#
# [9765 rows x 4 columns]

# %%
# cocina 3

# %%
h = '../data/001_raw/Cocina_3__sin_agua_lana_oveja__12_01_24.csv'

df3 = pd.read_csv(h, index_col = 0, parse_dates = True)
# renombrar el index
df3 = df3.rename_axis(index='Fecha')

df3 = df3.rename({'Tipo K, °C (SEN S/N: 21654195, LBL: T 3p)':'T_p3',
                'Tipo T, °C (SEN S/N: 21654195, LBL: T 3C)':'T_c3',
                'Tipo T, °C (SEN S/N: 21654195, LBL: T 3iv)':'T_vi3',
                'Tipo T, °C (SEN S/N: 21654195, LBL: T 3ev)':'T_ve3'
                  }, axis = 1)
# Out:
# C:\Users\USER.V\AppData\Local\Temp\ipykernel_524\1074929889.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df3 = pd.read_csv(h, index_col = 0, parse_dates = True)

# %%
df3
# Out:
#                       T_p3   T_c3  T_vi3  T_ve3
# Fecha
# 2024-01-05 15:00:00  88.96  75.19  59.88  43.49
# 2024-01-05 15:01:00  88.65  75.35  59.73  43.42
# 2024-01-05 15:02:00  88.18  74.16  59.48  42.87
# 2024-01-05 15:03:00  87.99  75.34  59.32  43.88
# 2024-01-05 15:04:00  87.77  75.18  59.18  44.03
# ...                    ...    ...    ...    ...
# 2024-01-12 09:35:00  62.63  28.18  59.58  48.54
# 2024-01-12 09:36:00  60.90  28.86  59.49  49.10
# 2024-01-12 09:37:00  59.79  29.55  59.51  49.55
# 2024-01-12 09:38:00  58.99  30.21  59.59  49.75
# 2024-01-12 09:39:00  58.56  31.08  59.84  50.26
#
# [9760 rows x 4 columns]

# %%
df1.describe()
# Out:
#               T_p1         T_c1        T_vi1        T_ve1
# count  9768.000000  9768.000000  9768.000000  9768.000000
# mean     53.429006    48.400676    37.538271    34.066190
# std      45.521541    39.194446    24.827990    21.594496
# min      16.050000    15.880000    16.110000    14.980000
# 25%      20.280000    20.070000    19.960000    18.950000
# 50%      26.695000    25.535000    23.360000    21.590000
# 75%      80.432500    71.230000    52.342500    47.817500
# max     154.810000   142.640000   109.540000    90.480000

# %%
df2.describe()
# Out:
#               T_p2         T_c2        T_vi2        T_ve2
# count  9765.000000  9765.000000  9765.000000  9765.000000
# mean    109.745739    44.799628    38.988886    32.668601
# std     762.667956    33.289145    27.366973    19.434827
# min    -888.880000    15.750000    14.930000     2.020000
# 25%      17.850000    20.120000    19.260000    18.940000
# 50%      27.330000    25.580000    23.070000    21.540000
# 75%     124.830000    65.390000    57.740000    46.330000
# max    2020.160000   120.560000   100.810000    78.450000

# %%
df3.describe()
# Out:
#               T_p3         T_c3        T_vi3        T_ve3
# count  9760.000000  9760.000000  9760.000000  9760.000000
# mean     49.530310    44.288693    37.653720    31.023411
# std      37.506635    31.112759    24.231956    16.383009
# min      16.150000    15.940000    15.240000    14.970000
# 25%      20.760000    20.410000    19.460000    19.040000
# 50%      27.880000    26.575000    23.860000    21.870000
# 75%      75.795000    65.315000    53.812500    42.190000
# max     127.170000   111.690000    91.990000    70.940000

# %% [markdown]
# # Concatenando las tres cocinas 1L de agua con tecnopor

# %%
tecn_sa = pd.concat([df1, df2, df3], axis = 1)
tecn_sa
# Out:
#                        T_p1   T_c1  T_vi1  T_ve1    T_p2   T_c2  T_vi2  T_ve2  \
# Fecha
# 2024-01-05 15:00:00  104.25  90.64  58.96  55.82 -888.88  78.06  63.84  48.38
# 2024-01-05 15:01:00  103.74  89.97  57.51  55.55 -888.88  76.85  63.49  48.11
# 2024-01-05 15:02:00  103.24  89.42  58.00  55.12 -888.88  75.19  63.18  47.74
# 2024-01-05 15:03:00  102.74  89.65  57.65  55.79 -888.88  76.95  62.95  48.33
# 2024-01-05 15:04:00  102.29  89.13  59.16  56.11 -888.88  76.73  62.73  48.36
# ...                     ...    ...    ...    ...     ...    ...    ...    ...
# 2024-01-12 09:43:00   59.53  46.30  84.17  54.01   63.48  40.73  66.35  55.73
# 2024-01-12 09:44:00   60.11  47.18  83.84  54.25   63.91  41.44  66.83  55.82
# 2024-01-12 09:45:00   60.75  47.87  84.12  55.28     NaN    NaN    NaN    NaN
# 2024-01-12 09:46:00   61.38  48.69  84.66  55.85     NaN    NaN    NaN    NaN
# 2024-01-12 09:47:00   62.04  49.51  85.45  56.06     NaN    NaN    NaN    NaN
#
#                       T_p3   T_c3  T_vi3  T_ve3
# Fecha
# 2024-01-05 15:00:00  88.96  75.19  59.88  43.49
# 2024-01-05 15:01:00  88.65  75.35  59.73  43.42
# 2024-01-05 15:02:00  88.18  74.16  59.48  42.87
# 2024-01-05 15:03:00  87.99  75.34  59.32  43.88
# 2024-01-05 15:04:00  87.77  75.18  59.18  44.03
# ...                    ...    ...    ...    ...
# 2024-01-12 09:43:00    NaN    NaN    NaN    NaN
# 2024-01-12 09:44:00    NaN    NaN    NaN    NaN
# 2024-01-12 09:45:00    NaN    NaN    NaN    NaN
# 2024-01-12 09:46:00    NaN    NaN    NaN    NaN
# 2024-01-12 09:47:00    NaN    NaN    NaN    NaN
#
# [9768 rows x 12 columns]

# %%
tecn_sa = tecn_sa.loc['2024-01-09 00:00:00':'2024-01-11 23:59:00']

# %%
tecn_sa
# Out:
#                       T_p1   T_c1  T_vi1  T_ve1   T_p2   T_c2  T_vi2  T_ve2  \
# Fecha
# 2024-01-09 00:00:00  18.29  18.01  17.62  16.55  18.43  17.95  16.75  16.34
# 2024-01-09 00:01:00  18.31  17.96  17.75  16.54  18.42  17.92  16.71  16.28
# 2024-01-09 00:02:00  18.27  17.96  17.93  16.58  18.39  17.97  16.67  16.32
# 2024-01-09 00:03:00  18.27  18.00  17.73  16.57  18.35  17.89  16.71  16.25
# 2024-01-09 00:04:00  18.22  17.94  17.78  16.55  18.34  17.95  16.66  16.38
# ...                    ...    ...    ...    ...    ...    ...    ...    ...
# 2024-01-11 23:55:00  21.49  21.33  21.20  20.34  21.69  21.48  20.68  20.35
# 2024-01-11 23:56:00  21.47  21.33  21.31  20.35  21.70  21.51  20.74  20.36
# 2024-01-11 23:57:00  21.46  21.33  21.32  20.35  21.78  21.44  20.68  20.37
# 2024-01-11 23:58:00  21.46  21.37  21.29  20.38  21.79  21.46  20.65  20.32
# 2024-01-11 23:59:00  21.50  21.33  21.29  20.39  21.72  21.46  20.66  20.40
#
#                       T_p3   T_c3  T_vi3  T_ve3
# Fecha
# 2024-01-09 00:00:00  18.87  18.43  17.11  16.55
# 2024-01-09 00:01:00  18.86  18.36  17.15  16.55
# 2024-01-09 00:02:00  18.80  18.35  17.13  16.55
# 2024-01-09 00:03:00  18.79  18.35  17.14  16.54
# 2024-01-09 00:04:00  18.73  18.34  17.14  16.57
# ...                    ...    ...    ...    ...
# 2024-01-11 23:55:00  22.23  21.95  21.03  20.58
# 2024-01-11 23:56:00  22.23  21.96  21.05  20.60
# 2024-01-11 23:57:00  22.23  21.93  21.03  20.60
# 2024-01-11 23:58:00  22.19  21.96  21.07  20.60
# 2024-01-11 23:59:00  22.19  21.96  21.04  20.59
#
# [4320 rows x 12 columns]

# %%
tecn_sa[['T_p1','T_p2','T_p3']].plot()
# Out:
# <Axes: xlabel='Fecha'>

# %%
tecn_sa[['T_c1','T_c2','T_c3']].plot()
# Out:
# <Axes: xlabel='Fecha'>

# %%
tecn_sa[['T_vi1','T_vi2','T_vi3']].plot()
# Out:
# <Axes: xlabel='Fecha'>

# %%
tecn_sa[['T_ve1','T_ve2','T_ve3']].plot()
# Out:
# <Axes: xlabel='Fecha'>

# %%
tecn_sa.plot(figsize = (20,10))
# Out:
# <Axes: xlabel='Fecha'>

# %%
tecn_sa.plot(subplots = True, figsize = (10,30))
# Out:
# array([<Axes: xlabel='Fecha'>, <Axes: xlabel='Fecha'>,
#        <Axes: xlabel='Fecha'>, <Axes: xlabel='Fecha'>,
#        <Axes: xlabel='Fecha'>, <Axes: xlabel='Fecha'>,
#        <Axes: xlabel='Fecha'>, <Axes: xlabel='Fecha'>,
#        <Axes: xlabel='Fecha'>, <Axes: xlabel='Fecha'>,
#        <Axes: xlabel='Fecha'>, <Axes: xlabel='Fecha'>], dtype=object)
